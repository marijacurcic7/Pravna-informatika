# %%
import os
import re
import nltk
import pandas as pd

# %%
rootdir = 'data'
filepaths = []

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        filename = os.path.join(subdir, file)
        filepaths.append(filename)

# %%
data = []
data_sentences = []
for file in filepaths:
    f = open(file, "r", encoding="utf8")
    sadrzaj = f.read()
    sadrzaj = sadrzaj.lower()
    sadrzaj = sadrzaj.replace("\n", " ")
    sadrzaj = sadrzaj.replace("*", "")
    sadrzaj = " ".join(sadrzaj.split()) #replace multiple whitespace characters with single space
    tokens = nltk.sent_tokenize(sadrzaj)
    row = [file, tokens]
    data.append(row)
    for t in tokens:
        row_sent = [t, '', file]
        data_sentences.append(row_sent)

# %%
df = pd.DataFrame(data=data, columns=['filename', 'sentences'])
df #red je fajl sa listom recenica
# Out:
#                                                filename  \
# 0     data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# 1     data\I - PREDMETI IZVRŠENJA\presuda_text_13358...
# 2     data\I - PREDMETI IZVRŠENJA\presuda_text_13359...
# 3      data\I - PREDMETI IZVRŠENJA\presuda_text_306.txt
# 4      data\I - PREDMETI IZVRŠENJA\presuda_text_307.txt
# ...                                                 ...
# 3499  data\Kr - RAZNE KRIVIČNE STVARI\presuda_text_6...
# 3500  data\Kr - RAZNE KRIVIČNE STVARI\presuda_text_7...
# 3501  data\Kr - RAZNE KRIVIČNE STVARI\presuda_text_7...
# 3502  data\Kr - RAZNE KRIVIČNE STVARI\presuda_text_7...
# 3503  data\Kr - RAZNE KRIVIČNE STVARI\presuda_text_8...
#
#                                               sentences
# 0     [i.br., 376/07 osnovni sud u nikšiću , sudija ...
# 1     [i br.209/12 osnovni sud u danilovgradu, po su...
# 2     [i br.192/12 osnovni sud u danilovgradu, po su...
# 3     [i.br.21/10 osnovni sud u podgorici , po sudij...
# 4     [i.br.637/11 osnovni sud u podgorici, po sudij...
# ...                                                 ...
# 3499  [vrhovni sud crne gore kr.br.51/12 vrhovni sud...
# 3500  [vrhovni sud crne gore kr.br., 14/12 vrhovni s...
# 3501  [vrhovni sud u podgorici kr.br.23/12 vrhovni s...
# 3502  [vrhovni sud crne gore kr.br.53/12 vrhovni sud...
# 3503  [vrhovni sud crne gore tpz., br., 65/12 vrhovn...
#
# [3504 rows x 2 columns]

# %%
df_sentences = pd.DataFrame(data=data_sentences, columns=['sentence', 'label', 'filename'])
df_sentences #red je jedna recenica sa labelom i nazivom fajla u kojem se nalazi
#sve labele su za sad prazna, bice 1 ili 0
# Out:
#                                                  sentence label  \
# 0                                                   i.br.
# 1       376/07 osnovni sud u nikšiću , sudija bojović ...
# 2                                                  ."….."
# 3       ad b., koju zastupa punomoćnik n.j. advokat iz...
# 4                           ----, po kulturi livada povr.
# ...                                                   ...   ...
# 424536  2012. godine podnosio kontrolni zahtjev i da j...
# 424537                                                09.
# 424538  2012. godine, kada je odbijena žalba tužioca i...
# 424539  ovo sa razloga što rok iz člana 33 st. 3 zakon...
# 424540  vrhovni sud crne gore podgorica 31.01.2013. go...
#
#                                                  filename
# 0       data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# 1       data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# 2       data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# 3       data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# 4       data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# ...                                                   ...
# 424536  data\Kr - RAZNE KRIVIČNE STVARI\presuda_text_8...
# 424537  data\Kr - RAZNE KRIVIČNE STVARI\presuda_text_8...
# 424538  data\Kr - RAZNE KRIVIČNE STVARI\presuda_text_8...
# 424539  data\Kr - RAZNE KRIVIČNE STVARI\presuda_text_8...
# 424540  data\Kr - RAZNE KRIVIČNE STVARI\presuda_text_8...
#
# [424541 rows x 3 columns]

# %%
for ind in df_sentences.index:
    if(ind>20):
        break
    print(ind)
    print(df_sentences['sentence'][ind])
# Out:
# 0
# i.br.
# 1
# 376/07 osnovni sud u nikšiću , sudija bojović andrija, uz sudjelovanje kadić dragice kao zapisničara, u pravnoj stvari izvršnog povjerioca s p.
# 2
# ."….."
# 3
# ad b., koju zastupa punomoćnik n.j. advokat iz p., protiv izvršnog dužnika m. ž. iz n radi naplate novčanog potraživanja prodajom nekretnina izvršnog dužnika, dana 26.09.2011.g., donio je zaključak o prodaji određuje se ii-go ročište za prodaju nekretnina izvršnog dužnika, upisanih u listu nepokretnosti br---- ko r-, kat.parcela br.
# 4
# ----, po kulturi livada povr.
# 5
# 1229m2, dvorište 500m2, objekat u izgradnji povr.
# 6
# 64m2 i zgrada poljoprivrede povr.69m2, ili ukupne povr.
# 7
# 1862m2, putem usmenog, javnog nadmetanja, dana 2.11.2011.g.
# 8
# u 11 časova, kancelarija br.
# 9
# 14 ovoga suda.
# 10
# vrijednost opisanih nepokretnosti iznosi 32.889,00 evra i na ovom ročištu se mogu prodati ispod utvrđene vrijednosti, ali ne ispod 2/3 vrijednosti.
# 11
# vrijednost nepokretnosti može se ponovo utvrditi na ročištu za prodaju, na predlog stranke koji mora biti podnesen najdocnije 8 dana prije ročišta za prodaju.
# 12
# lica zainteresovana za učešće na usmenom, javnom nadmetanju, osim izvršnog povjerilaca, dužna su da u depozit suda u gotovom ili na žiro račun br------------ na ime jemstva uplate iznos od 10% utvrđene vrijednosti i da na javnom nadmetanju polože dokaz o tome.
# 13
# najbolji ponudilac - kupac kome nepokretgnost bude prodata dužan je da utvrđenu cijenu za koju je nepokretnost prodata položi u depozit suda u roku od 15 dana od zaključenja usmenog, javnog nadmetanja.
# 14
# ako kupac u tom roku ne položi cijenu prodaja će se oglasiti nevažećom i odrediti nova prodaja a u tom slučaju će se iz položenog jemstva od strane kupca izmiriti troškovi nove prodaje.
# 15
# zaključak o prodaji objaviti na oglasnoj tabli suda.
# 16
# osnovni sud u nikšiću , dana 26.09.2011.g.
# 17
# zapisničar s u d i j a kadić dragica,s.r.
# 18
# bojović andrija,s.r.
# 19
# d-na 26.09.2011.g.
# 20
# zaključak dostaviti: \- strankama \- u spisima postupljeno: s u d i j a

# %%
df_sentences[:70]
# Out:
#                                              sentence label  \
# 0                                               i.br.
# 1   376/07 osnovni sud u nikšiću , sudija bojović ...
# 2                                              ."….."
# 3   ad b., koju zastupa punomoćnik n.j. advokat iz...
# 4                       ----, po kulturi livada povr.
# ..                                                ...   ...
# 65  za troškove vještačenja i izlaska suda na lice...
# 66  na osnovu izloženog a shodno čl.184, 185, 240 ...
# 67  osnovni sud u podgorici dana, 10.03.2011.godin...
# 68  pravna pouka: protiv ovog rješenja može se izj...
# 69  za tačnost otpravka tvrdi i ovjerava namješten...
#
#                                              filename
# 0   data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# 1   data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# 2   data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# 3   data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# 4   data\I - PREDMETI IZVRŠENJA\presuda_text_1304.txt
# ..                                                ...
# 65   data\I - PREDMETI IZVRŠENJA\presuda_text_306.txt
# 66   data\I - PREDMETI IZVRŠENJA\presuda_text_306.txt
# 67   data\I - PREDMETI IZVRŠENJA\presuda_text_306.txt
# 68   data\I - PREDMETI IZVRŠENJA\presuda_text_306.txt
# 69   data\I - PREDMETI IZVRŠENJA\presuda_text_306.txt
#
# [70 rows x 3 columns]

# %%
df_sentences[:70].to_csv('csv_sentences70.csv')
